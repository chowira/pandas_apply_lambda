# %% [markdown]
# ### Pandas Apply Lambda
#
# Always remember the Zen of Python!!!

# %%
import pandas as pd

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
 work_df = pd.read_csv("../data/input/IMDB-Movie-Data.csv")
work_df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#funcion challenger 1
def create_bin(x):
    if x in range(0,1000):
        return "cat 1"
    elif x in range(999,10000):
        return  "cat 2"
    elif x in range(9999,100000):
        return "cat 3"
    elif  x in range(99999,1000000):
        return "cat 4"
    elif x >= 1000000:
        return "cat 5"

# %%
work_df["bin"] = work_df.apply(lambda row : create_bin(row["Votes"]), axis =1)
work_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
create_bin(9999999)
# Out:
# 'cat 5'

# %%
f.apply(lambda x: func( x['col1'], x['col2']), axis=1 )

# %%
work_df["bin"] = work_df["Votes"].apply(create_bin)
work_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
cost_for_minutes = work_df["Runtime (Minutes)"] / work_df["Revenue (Millions)"]
cost_for_minutes
# Out:
# 0      0.363222
# 1      0.980547
# 2      0.847089
# 3      0.399526
# 4      0.378438
#          ...
# 995         NaN
# 996    5.359179
# 997    1.689364
# 998         NaN
# 999    4.429735
# Length: 1000, dtype: float64

# %%
lambda row :row(["Runtime (Minutes)"]/work_df["Revenue (Millions)"], axis = 1)
# Out:
# <function __main__.<lambda>(row)>

# %%
f.apply(lambda x: func( x['col1'], x['col2']), axis=1 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 f.apply(lambda x: func( x['col1'], x['col2']), axis=1 )
#
# NameError: name 'f' is not defined

# %%
work_df[["Runtime (Minutes)"]].apply(lambda row :row /work_df["Revenue (Millions)"])
# Out:
#      Runtime (Minutes)
# 0             0.363222
# 1             0.980547
# 2             0.847089
# 3             0.399526
# 4             0.378438
# ..                 ...
# 995                NaN
# 996           5.359179
# 997           1.689364
# 998                NaN
# 999           4.429735
#
# [1000 rows x 1 columns]

# %%
 work_df["ganacias por minuto"] = work_df[["Revenue (Millions)"]].apply(lambda row :row /work_df["Runtime (Minutes)"])

# %%
work_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
work_df[["Runtime (Minutes)"]].apply(lambda row :row /work_df["Revenue (Millions)"])

# %%
 work_df["new rating"] = work_df[["Revenue (Millions)"]].apply(lambda row :row /work_df["Runtime (Minutes)"])

# %%
work_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#challeger 3
def new_rating(genre,rating):
    lista_generos = [genero.strip().lower() for genero in generos.split(',')]
    for genero in lista_generos:
        if "thriller" in lista_generos:
            return rating + 1
        elif "comedy" in lista_generos:
            return  rating -1
        else:
            return rating

# %%
#prueba
new_rating("Comedy,action",7)
# Out:
# 6

# %%
f.apply(lambda x: func( x['col1'], x['col2']), axis=1 )

# %%
work_df['Adjusted_Rating'] = work_df.apply(lambda row:new_rating (row['Genre'], row['Rating']), axis=1)

# %%
work_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#4 CHALLERGER 4
#Challenge 4. We want to know whether the integer part of the number resulting from the sum of the ASCII value of every character of the movie title divided by the number of votes, is a prime number (remember that prime numbers are integers

# %%
#definimos lo que queremos hacer con la funcion
#queremos que el agarre el titulo parta el string en letras separas y sume el valor ascii de cada letra y lo divida por el numero de votos
def ASCII_prime(string,votes):

# %%
hola= "hola"
vote= 15

# %%
ord("a")
# Out:
# 97

# %%
ord("o")
# Out:
# 111

# %%
lista_valor = []
for element in hola:
    valor = ord(element)
    lista_valor.append(valor)
    valor_ascii = int(sum(lista_valor)/votes)
    valor_ascii % 2 == 0
    
print(valor_ascii)
# Out:
# 28

# %%
def ASCII_prime(string,votes):
    lista_valor = []
    for element in string:
        valor = ord(element)
        lista_valor.append(valor)
        valor_ascii = int(sum(lista_valor)/votes) 
        return valor_ascii % 2 == 0
        print(valor_acsii)

# %%
ASCII_prime("hola",11)
#al probar vemos que nunca se ponia en true debido a que daba un float comoresultado de la duma y divicion que da el valor ascii
# Out:
# False

# %%
#ahora vemos que funciona correctamente y que la funcion da lo que queremos que es un numero entero para dividirlo entre 2 y ver si es par o no si no lo conviertes en entero nunca se cumplira la condicion
#ahora vamos a hacer uso de la funcion

# %%
work_df.apply(lambda row: ASCII_prime(row['Title'], row['Votes']), axis=1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Length: 1000, dtype: bool

# %%
work_df["title(ASCII)/vote/%"] = work_df.apply(lambda row: ASCII_prime(row['Title'], row['Votes']), axis=1)

# %%
work_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
work_df["title(ASCII)/vote/%"].unique() #comprobamos que no solo tenemos valrores true
# Out:
# array([ True, False])
